# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Matplotlib Pyplot

# %%
x = np.array ([0,6])
y =  np.array ([0,250])

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Matplotlib Plotting

# %%
y = np.array([3,10])
x = np.array([1,8])

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Matplotlib Markes

# %%
y = np.array([3,8,10,1,7])

plt.plot(y, marker = 'o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y = np.array([3,8,10,1,7])

plt.plot(y, marker = '*')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Matplotlib Line

# %%
y = np.array([3,8,1,10])

plt.plot(y, linestyle = 'dotted')
plt.show()

# %% [markdown]
# ### Matplotlib Label

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)
plt.xlabel('Average Pule')
plt.ylabel('Calorie Burnage')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)
plt.title('Sports Watch Data')
plt.xlabel('Average Pule')
plt.ylabel('Calorie Burnage')
plt.show()

# %% [markdown]
# ### Matplotlib Grid

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)
plt.title('Sports Watch Data')
plt.xlabel('Average Pule')
plt.ylabel('Calorie Burnage')

plt.grid()
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)
plt.title('Sports Watch Data')
plt.xlabel('Average Pule')
plt.ylabel('Calorie Burnage')

plt.grid(axis = 'x')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)
plt.title('Sports Watch Data')
plt.xlabel('Average Pule')
plt.ylabel('Calorie Burnage')

plt.grid(axis = 'y')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)
plt.title('Sports Watch Data')
plt.xlabel('Average Pule')
plt.ylabel('Calorie Burnage')

plt.grid(color = 'blue', linestyle = '--' , linewidth = 0.5)
plt.show()

# %% [markdown]
# ### Matplotlib Subplot

# %%
plt.subplot(1,2,1)
#the figure has 1 row, 2 columns, and this plot is the first plot

plt.subplot(1,2,2)
#the figure has 1 row, 2 columns, and this plot is the second plot.
# Out:
# <Axes: >

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2,1,1)
plt.plot (x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2,1,2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])

plt.subplot(2,3,1)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])

plt.subplot(2,3,2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Matplotlib Scater

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y)
plt.show()

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# ### Matplotlib Bars

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# ### Matplotlib Histogram

# %%
x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [180.51707403 157.04371059 167.88458244 180.34700425 173.66950525
#  167.84948175 186.49279688 169.13413327 174.1451786  149.75336923
#  160.78445806 157.56018417 171.56950646 165.08042171 145.58365624
#  168.01433516 164.84941205 174.20979416 171.77862216 185.98978603
#  178.72938605 156.3222811  187.17197578 170.35256866 175.30955364
#  170.1629711  161.70942226 174.39201017 174.92196224 187.17094037
#  167.53953477 178.69619644 163.55832026 166.17187232 168.94037815
#  174.80671378 163.59873708 164.06621413 160.30000494 178.26082096
#  172.85115232 186.88154797 173.07600723 165.27045679 162.49704005
#  168.37514992 153.41061878 160.7671439  173.52240639 175.93260116
#  160.37474303 165.20966489 178.79412181 151.54015249 160.15493942
#  176.30705189 170.15589352 170.64521962 178.03870454 184.99400663
