# %% [markdown]
# ###### import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# %%
# membantu hrd utk memastikan seorang kandidat
# jabatan sebelum : region manager
# gaji : 165000 per year
# manager hrd : permintaannya benar atau salah
# jawab dengan model yg bisa memprediksi salary berdasasr level jabatan
# buat prediksi gaji dengan level 6.5 (165000)
dataset = pd.read_csv('Position_Salaries.csv')
datas
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
X = datas.iloc[:,1:-1] #[semua baris, mengambil kolom level]
y = datas.iloc[:,-1]#[semua baris, kolom yang terakhir saja]

# %% [markdown]
# ## training the linear regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the polynomial linear regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the linear regression result

# %%
# grafik scatter
plt.scatter(X,y,color = 'red')
# grafik linear regresi
plt.plot(X,lin_reg.predict(X),color = 'blue')
plt.title('Truth or bluff')
plt.xlabel('Level position')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the polynomial linear regression result

# %%
plt.scatter(X,y,color = 'red')
plt.plot(X, lin_reg_2.predict(X_poly), color='green', label='Regresi Linier Polinomial')
plt.title('Truth or bluff')
plt.xlabel('Level position')
plt.ylabel('Salary')
plt.show()
