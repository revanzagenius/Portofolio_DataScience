# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("backloggd_games.csv")
df.head()
# Out:
#    Unnamed: 0                                    Title  Release_Date  \
# 0           0                               Elden Ring  Feb 25, 2022
# 1           1  The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 2           2                                    Hades  Dec 07, 2018
# 3           3                            Hollow Knight  Feb 24, 2017
# 4           4                                Undertale  Sep 15, 2015
#
#                                           Developers  \
# 0     ['FromSoftware', 'Bandai Namco Entertainment']
# 1  ['Nintendo', 'Nintendo EPD Production Group No...
# 2                               ['Supergiant Games']
# 3                                    ['Team Cherry']
# 4                                 ['tobyfox', '8-4']
#
#                                              Summary  \
# 0  Elden Ring is a fantasy, action and open world...
# 1  The Legend of Zelda: Breath of the Wild is the...
# 2  A rogue-lite hack and slash dungeon crawler in...
# 3  A 2D metroidvania with an emphasis on close co...
# 4  A small child falls into the Underground, wher...
#
#                                            Platforms  \
# 0  ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...
# 1                       ['Wii U', 'Nintendo Switch']
# 2  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox O...
# 3  ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch']
# 4  ['Windows PC', 'Mac', 'Linux', 'PlayStation 4'...
#
#                                               Genres  Rating Plays Playing  \
# 0                               ['Adventure', 'RPG']     4.5   21K    4.1K
# 1                            ['Adventure', 'Puzzle']     4.4   35K    3.1K
# 2           ['Adventure', 'Brawler', 'Indie', 'RPG']     4.3   25K    3.5K
# 3                 ['Adventure', 'Indie', 'Platform']     4.4   25K    2.7K
# 4  ['Adventure', 'Indie', 'RPG', 'Turn Based Stra...     4.2   32K     728
#
#   Backlogs Wishlist Lists Reviews
# 0     5.6K     5.5K  4.6K      3K
# 1     5.6K       3K  5.1K      3K
# 2     7.3K       4K  3.2K    2.1K
# 3     9.6K     2.6K  3.4K    2.1K
# 4     5.7K     2.1K  3.9K    2.5K

# %%
df.describe()
# Out:
#          Unnamed: 0        Rating
# count  60000.000000  25405.000000
# mean   29999.500000      3.033171
# std    17320.652413      0.735573
# min        0.000000      0.300000
# 25%    14999.750000      2.600000
# 50%    29999.500000      3.100000
# 75%    44999.250000      3.500000
# max    59999.000000      5.000000

# %%
df.isnull()
# Out:
#        Unnamed: 0  Title  Release_Date  Developers  Summary  Platforms  \
# 0           False  False         False       False    False      False
# 1           False  False         False       False    False      False
# 2           False  False         False       False    False      False
# 3           False  False         False       False    False      False
# 4           False  False         False       False    False      False
# ...           ...    ...           ...         ...      ...        ...
# 59995       False  False         False       False    False      False
# 59996       False  False         False       False    False      False
# 59997       False  False         False       False    False      False
# 59998       False  False         False       False    False      False
# 59999       False  False         False       False    False      False
#
#        Genres  Rating  Plays  Playing  Backlogs  Wishlist  Lists  Reviews
# 0       False   False  False    False     False     False  False    False
# 1       False   False  False    False     False     False  False    False
# 2       False   False  False    False     False     False  False    False
# 3       False   False  False    False     False     False  False    False
# 4       False   False  False    False     False     False  False    False
# ...       ...     ...    ...      ...       ...       ...    ...      ...
# 59995   False    True  False    False     False     False  False    False
# 59996   False   False  False    False     False     False  False    False
# 59997   False    True  False    False     False     False  False    False
# 59998   False    True  False    False     False     False  False    False
# 59999   False   False  False    False     False     False  False    False
#
# [60000 rows x 14 columns]

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 59995    False
# 59996    False
# 59997    False
# 59998    False
# 59999    False
# Length: 60000, dtype: bool

# %%
df.shape
# Out:
# (60000, 14)

# %%
unique_ratings = (df["Rating"].unique())
print(unique_ratings)
# Out:
# [4.5 4.4 4.3 4.2 4.1 4.6 3.  3.7 3.8 3.4 2.6 3.9 4.  2.8 3.6 3.5 3.2 2.1
#  3.3 2.7 3.1 1.6 2.9 2.4 2.5 1.9 nan 1.8 2.3 2.  1.4 1.1 1.5 2.2 4.8 0.8
#  1.7 4.7 0.7 1.2 1.3 5.  1.  0.9 4.9 0.3 0.5 0.6]

# %%
df.dropna()
# Out:
#        Unnamed: 0                                       Title  Release_Date  \
# 0               0                                  Elden Ring  Feb 25, 2022
# 1               1     The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 2               2                                       Hades  Dec 07, 2018
# 3               3                               Hollow Knight  Feb 24, 2017
# 4               4                                   Undertale  Sep 15, 2015
# ...           ...                                         ...           ...
# 59973       59973                             FIFA Manager 14  Oct 24, 2013
# 59978       59978                                Super Widget  Feb 01, 1993
# 59981       59981                          Pizza Delivery Boy  Apr 18, 2010
# 59996       59996  Pathfinder: Kingmaker - Definitive Edition  Aug 18, 2020
# 59999       59999  Pathfinder: Kingmaker - Definitive Edition  Aug 18, 2020
#
#                                               Developers  \
# 0         ['FromSoftware', 'Bandai Namco Entertainment']
# 1      ['Nintendo', 'Nintendo EPD Production Group No...
# 2                                   ['Supergiant Games']
# 3                                        ['Team Cherry']
# 4                                     ['tobyfox', '8-4']
# ...                                                  ...
# 59973               ['Bright Future', 'Electronic Arts']
# 59978                                                 []
# 59981                                                 []
# 59996                    ['Owlcat Games', 'Deep Silver']
# 59999                    ['Owlcat Games', 'Deep Silver']
#
#                                                  Summary  \
# 0      Elden Ring is a fantasy, action and open world...
# 1      The Legend of Zelda: Breath of the Wild is the...
# 2      A rogue-lite hack and slash dungeon crawler in...
# 3      A 2D metroidvania with an emphasis on close co...
# 4      A small child falls into the Underground, wher...
# ...                                                  ...
# 59973  FIFA Manager 14: Legacy Edition is a re-releas...
# 59978  Planet Earth is in danger from assorted villai...
# 59981  When three brothers mismanage their successful...
# 59996  The Definitive Edition will have all of the DL...
# 59999  The Definitive Edition will have all of the DL...
#
#                                                Platforms  \
# 0      ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...
# 1                           ['Wii U', 'Nintendo Switch']
# 2      ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox O...
# 3      ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch']
# 4      ['Windows PC', 'Mac', 'Linux', 'PlayStation 4'...
# ...                                                  ...
# 59973                                     ['Windows PC']
# 59978                                           ['SNES']
# 59981                                            ['Wii']
# 59996                      ['PlayStation 4', 'Xbox One']
# 59999                      ['PlayStation 4', 'Xbox One']
#
#                                                   Genres  Rating Plays  \
# 0                                   ['Adventure', 'RPG']     4.5   21K
# 1                                ['Adventure', 'Puzzle']     4.4   35K
# 2               ['Adventure', 'Brawler', 'Indie', 'RPG']     4.3   25K
# 3                     ['Adventure', 'Indie', 'Platform']     4.4   25K
# 4      ['Adventure', 'Indie', 'RPG', 'Turn Based Stra...     4.2   32K
# ...                                                  ...     ...   ...
# 59973                                          ['Sport']     2.5     6
# 59978                                       ['Platform']     2.7    23
# 59981                                         ['Puzzle']     0.7     3
# 59996                                ['RPG', 'Tactical']     3.7     9
# 59999                                ['RPG', 'Tactical']     3.7     9
#
#       Playing Backlogs Wishlist Lists Reviews
# 0        4.1K     5.6K     5.5K  4.6K      3K
# 1        3.1K     5.6K       3K  5.1K      3K
# 2        3.5K     7.3K       4K  3.2K    2.1K
# 3        2.7K     9.6K     2.6K  3.4K    2.1K
# 4         728     5.7K     2.1K  3.9K    2.5K
# ...       ...      ...      ...   ...     ...
# 59973       0        4        0     1       0
# 59978       0        4        3    10       0
# 59981       0        0        1     1       0
# 59996       0       19        1     7       1
# 59999       0       19        1     7       1
#
# [24801 rows x 14 columns]

# %%
print(df.loc[df['Rating'].isnull()])
# Out:
#        Unnamed: 0                              Title  Release_Date  \
# 526           526                  Final Fantasy XVI  Jun 22, 2023
# 634           634                           Hades II           TBD
# 660           660            Hollow Knight: Silksong  Dec 31, 2023
# 663           663  Armored Core VI: Fires of Rubicon  Aug 25, 2023
# 688           688                   Persona 3 Reload  Dec 31, 2024
# ...           ...                                ...           ...
# 59993       59993             No Country for Old Men           TBD
# 59994       59994                             Sainth  Apr 11, 2008
# 59995       59995                     Dragon Spirits  Apr 25, 2023
# 59997       59997                             Sainth  Apr 11, 2008
# 59998       59998                     Dragon Spirits  Apr 25, 2023
#
#                                    Developers  \
# 526                           ['Square Enix']
# 634                      ['Supergiant Games']
# 660                           ['Team Cherry']
# 663    ['Bandai Namco Games', 'FromSoftware']
# 688                         ['Sega', 'Atlus']
# ...                                       ...
# 59993                                      []
# 59994                          ['Neo Kuriyo']
# 59995                 ['FHNBHJ', 'indienova']
# 59997                          ['Neo Kuriyo']
# 59998                 ['FHNBHJ', 'indienova']
#
#                                                  Summary  \
# 526    Final Fantasy XVI is an upcoming action role-p...
# 634    Battle beyond the Underworld using dark sorcer...
# 660    Explore a vast, haunted kingdom in Hollow Knig...
# 663    By combining FromSoftware’s longstanding exper...
# 688    Persona 3 Reload is an upcoming remake of Pers...
# ...                                                  ...
# 59993  This is a game combines SIM and SRPG. Please l...
# 59994  Years after the events of "Wraith", a young gi...
# 59995  While constantly working on a video game witho...
# 59997  Years after the events of "Wraith", a young gi...
# 59998  While constantly working on a video game witho...
#
#                                                Platforms  \
# 526                      ['Windows PC', 'PlayStation 5']
# 634                                       ['Windows PC']
# 660    ['Windows PC', 'Mac', 'Linux', 'PlayStation 4'...
# 663    ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...
# 688    ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...
# ...                                                  ...
# 59993                                                 []
# 59994                                     ['Windows PC']
# 59995                                     ['Windows PC']
# 59997                                     ['Windows PC']
# 59998                                     ['Windows PC']
#
#                                           Genres  Rating Plays Playing  \
# 526                                      ['RPG']     NaN    83      83
# 634                ['Adventure', 'Indie', 'RPG']     NaN    16       3
# 660           ['Adventure', 'Indie', 'Platform']     NaN    98       8
# 663                                ['Adventure']     NaN     8       5
# 688                                      ['RPG']     NaN    13       1
# ...                                          ...     ...   ...     ...
# 59993  ['Indie', 'RPG', 'Simulator', 'Strategy']     NaN     0       0
# 59994                                         []     NaN     1       0
# 59995                                    ['RPG']     NaN     2       0
# 59997                                         []     NaN     1       0
# 59998                                    ['RPG']     NaN     2       0
#
#       Backlogs Wishlist Lists Reviews
# 526       1.2K     3.1K   509      11
# 634        659     1.9K   181       1
# 660       1.3K       4K   331      16
# 663        401     1.2K   248       0
# 688        283     1.1K   130       0
# ...        ...      ...   ...     ...
# 59993        0        0     0       0
# 59994        0        2     0       0
# 59995        1        5     3       0
# 59997        0        2     0       0
# 59998        1        5     3       0
#
# [34595 rows x 14 columns]
